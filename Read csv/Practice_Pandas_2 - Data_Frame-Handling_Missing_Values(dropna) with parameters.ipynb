# %% [markdown]
# # Handling Missing Values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %% [markdown]
# # Missing Vlaues consider

# %% [markdown]
# - #N/A
# - -NaN
# - null
# - -nan
# - -n/a
# -  #NA
# - N/A
# - nan
# - -1.#IND
# - NA
# - 1.#IND
# - -1.#QNAN
# -  Null
# - 1.#QNAN

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv",keep_default_na=True)
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv",keep_default_na=False)
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     #NA                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv",na_filter=False)
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     #NA                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv",na_filter=True)
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %% [markdown]
# -  isnull()
# -  notnull()
# -  isnull().sum()
# -  notnull().sum()
# -  isnull().sum().sum()
# -  notnull().sum().sum()

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.isnull()
# Out:
#     Student Code  Degree  Student_Name    Mid  Quiz 1  Quiz 2  \
# 0          False   False         False  False   False   False
# 1          False   False         False  False    True   False
# 2          False   False         False  False   False   False
# 3          False   False         False  False   False   False
# 4          False   False         False  False   False   False
# 5          False   False         False  False   False   False
# 6          False   False         False  False   False   False
# 7          False   False         False  False   False   False
# 8          False   False         False  False   False   False
# 9          False   False         False  False   False   False
# 10         False   False         False  False   False   False
# 11         False   False         False  False   False   False
# 12         False   False         False  False   False   False
# 13         False   False         False  False   False   False
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.notnull().sum()  # how many not nul values
# Out:
# Student Code            48
# Degree                  47
# Student_Name            48
# Mid                     48
# Quiz 1                  45
# Quiz 2                  45
# Best of Quizzes         48
# Assignment 1            45
# Assignment 2            36
# Best of Assignments     47
# Total Sessional (50)    47
# Final (50)              45
# Total (100)             46
# Grade                   48
# True_values             48
# False_values            48
# dtype: int64

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.isnull().sum()  #How many null values
# Out:
# Student Code             0
# Degree                   1
# Student_Name             0
# Mid                      0
# Quiz 1                   3
# Quiz 2                   3
# Best of Quizzes          0
# Assignment 1             3
# Assignment 2            12
# Best of Assignments      1
# Total Sessional (50)     1
# Final (50)               3
# Total (100)              2
# Grade                    0
# True_values              0
# False_values             0
# dtype: int64

# %% [markdown]
# HOw many total null values in dataset

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.isnull().sum().sum()
# Out:
# 29

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.notnull().sum().sum()
# Out:
# 739

# %%
#Series
s1=pd.Series([2,3,5,np.nan,np.NaN,34,5])
s1
# Out:
# 0     2.0
# 1     3.0
# 2     5.0
# 3     NaN
# 4     NaN
# 5    34.0
# 6     5.0
# dtype: float64

# %%
s1.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# 6    False
# dtype: bool

# %%
s1.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# dtype: bool

# %% [markdown]
# # dropna() Method
# use to drop the null values in dataset

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data
# Out:
#      Student Code  Degree                    Student_Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna()
# Out:
#      Student Code  Degree                    Student_Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# ...

# %% [markdown]
# # Dropna with axis

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna(axis=1)
# Out:
#      Student Code                    Student_Name           Mid  \
# 0    022-14-19987                     Abdul Basit  not avalible
# 1   022-14-110233                     Adeel Ahmed            17
# 2   022-14-110585                    Afrah Zareen            18
# 3    022-14-19718                  Ahmed Ali Raza            14
# 4   022-14-110648                 Ahsan Ali Vohra            27
# 5   022-14-110232                     Ameer Hamza            25
# 6   022-14-110588                   Anas Ali Khan            28
# 7   022-14-110388                Aneebullah Niazi            26
# 8   022-14-110601                  Areesha Sohail            19
# 9   022-14-110599                         Arsalan            28
# 10  022-14-110214             Fatima Haider Warsi            30
# 11  022-14-110591                     Habib Ullah            28
# 12  022-15-110994             Hafiza Tooba Akbani            23
# 13  022-14-110600              Hamza Abdul Jabbar            24
# ...

# %% [markdown]
# # dropna with axis 0

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna(axis=0)
# Out:
#      Student Code  Degree                    Student_Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# ...

# %% [markdown]
# # dropna with how parameter

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna(how="any") # jis column me NA values hongi drop kr dy ga
# Out:
#      Student Code  Degree                    Student_Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani   23     7.0
# 13  022-14-110600  BS(CS)              Hamza Abdul Jabbar   24     8.0
# 14  022-14-110389  BS(CS)                   Hareem Afshan   21     7.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 17  022-14-110396  BS(CS)                    Khalid Anwer   20     8.0
# ...

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna(how="any")  # ye defualt values ki trha NA values k sth return ke dyta hai...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d31960391276> in <module>
# ----> 1 data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
#       2 data.dropna(how="any")  # ye defualt values ki trha NA values k sth return ke dyta hai...
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # dropna all parameter

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv")
data.dropna(axis=1)  # coloumns
# Out:
#      Student Code                    Student_Name           Mid  \
# 0    022-14-19987                     Abdul Basit  not avalible
# 1   022-14-110233                     Adeel Ahmed            17
# 2   022-14-110585                    Afrah Zareen            18
# 3    022-14-19718                  Ahmed Ali Raza            14
# 4   022-14-110648                 Ahsan Ali Vohra            27
# 5   022-14-110232                     Ameer Hamza            25
# 6   022-14-110588                   Anas Ali Khan            28
# 7   022-14-110388                Aneebullah Niazi            26
# 8   022-14-110601                  Areesha Sohail            19
# 9   022-14-110599                         Arsalan            28
# 10  022-14-110214             Fatima Haider Warsi            30
# 11  022-14-110591                     Habib Ullah            28
# 12  022-15-110994             Hafiza Tooba Akbani            23
# 13  022-14-110600              Hamza Abdul Jabbar            24
# ...

# %% [markdown]
# # Thresh parameter
#  kaam az kaam values ko drop krta hai

# %%
data=pd.read_csv("D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\Book1.csv")
data.dropna(thresh=3)
# Out:
#        Date     Name  Age Course
# 0  1/1/2019    Sadiq   23     AI
# 1       NaN  Shahdad   45     AI
# 3  1/4/2019     Anus   55     AI
# 4  1/5/2019   Faisal   34     AI
# 5  1/6/2019    sadiq   33     AI
# 6  1/7/2019   Kashif   12     AI
# 7  1/8/2019      NaN   35     AI
# 8  1/9/2019    Ahsan   67     AI

# %%
data.dropna(thresh=4)
# Out:
#        Date    Name  Age Course
# 0  1/1/2019   Sadiq   23     AI
# 3  1/4/2019    Anus   55     AI
# 4  1/5/2019  Faisal   34     AI
# 5  1/6/2019   sadiq   33     AI
# 6  1/7/2019  Kashif   12     AI
# 8  1/9/2019   Ahsan   67     AI

# %% [markdown]
# # Inplace
# - inplace use to drop the all null value but not generate new data frame ..changes in default data frame

# %%
data.dropna(inplace=True)
data
# Out:
#        Date    Name  Age Course
# 0  1/1/2019   Sadiq   23     AI
# 3  1/4/2019    Anus   55     AI
# 4  1/5/2019  Faisal   34     AI
# 5  1/6/2019   sadiq   33     AI
# 6  1/7/2019  Kashif   12     AI
# 8  1/9/2019   Ahsan   67     AI

# %%
data.dropna()
