# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # LOC:
#     - it is use to acsess by label or boolean array
#     -Single label
#     - more than labels

# %%
data=pd.read_csv('D:\\PIAIC DOC\\Q2\\pandas\\PRACTICE\\Read CSV\\data.csv')
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data.loc[1]
# Out:
# Student Code            022-14-110233
# Degree                         BS(CS)
# Student_Name              Adeel Ahmed
# Mid                                17
# Quiz 1                            NaN
# Quiz 2                              5
# Best of Quizzes                     5
# Assignment_1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               32
# Final_50                           18
# Total_100                          50
# Grade                               F
# True_values                       yes
# False_values                       No
# Name: 1, dtype: object

# %%
#by slicing
data.loc[1:2]
# Out:
#     Student Code  Degree  Student_Name Mid Quiz 1 Quiz 2 Best of Quizzes  \
# 1  022-14-110233  BS(CS)   Adeel Ahmed  17    NaN      5               5
# 2  022-14-110585  BS(CS)  Afrah Zareen  18   Null      2               5
#
#   Assignment_1 Assignment 2  Best of Assignments  Total Sessional (50)  \
# 1            8           10                 10.0                  32.0
# 2            8           10                 10.0                  33.0
#
#   Final_50  Total_100 Grade True_values False_values
# 1       18       50.0     F         yes           No
# 2       30       63.0     C         yes     avalible

# %%
# fancy indexing///
data.loc[[0,4]]
# Out:
#     Student Code  Degree     Student_Name           Mid Quiz 1 Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit  not avalible      8   Null
# 4  022-14-110648     NaN  Ahsan Ali Vohra            27      7      6
#
#   Best of Quizzes Assignment_1  Assignment 2  Best of Assignments  \
# 0               8            7  not avalible                  9.0
# 4               7            7             9                  9.0
#
#    Total Sessional (50) Final_50  Total_100 Grade True_values False_values
# 0                  45.0       25       70.0     B         yes           No
# 4                  43.0       34       77.0     B         yes           No

# %%
#index with column....
data.loc[3,"Mid"]
# Out:
# '14'

# %%
data.loc[0:6,"Grade"]
# Out:
# 0    B
# 1    F
# 2    C
# 3    F
# 4    B
# 5    B
# 6    B
# Name: Grade, dtype: object

# %%
#boolean vaues....
data.loc[[False,False,False,True]]
# Out:
#    Student Code  Degree    Student_Name Mid Quiz 1 Quiz 2 Best of Quizzes  \
# 3  022-14-19718  BS(CS)  Ahmed Ali Raza  14      7      2               7
#
#   Assignment_1 Assignment 2  Best of Assignments  Total Sessional (50)  \
# 3          NaN            2                  2.0                  23.0
#
#   Final_50  Total_100 Grade True_values False_values
# 3      NaN       46.0     F         yes           No

# %%
#conditional values//
data.loc[data["Total_100"]>=50]
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# 12  022-15-110994  BS(CS)             Hafiza Tooba Akbani            23
# ...

# %%
data.loc[data["Total_100"]>40,"Mid"]
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %% [markdown]
# # ILOC
# - integer location-Based indexing.
# - Coloum wise print kry ga

# %%
data
# Out:
#      Student Code  Degree                    Student_Name           Mid  \
# 0    022-14-19987  BS(CS)                     Abdul Basit  not avalible
# 1   022-14-110233  BS(CS)                     Adeel Ahmed            17
# 2   022-14-110585  BS(CS)                    Afrah Zareen            18
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza            14
# 4   022-14-110648     NaN                 Ahsan Ali Vohra            27
# 5   022-14-110232  BS(CS)                     Ameer Hamza            25
# 6   022-14-110588  BS(CS)                   Anas Ali Khan            28
# 7   022-14-110388  BS(CS)                Aneebullah Niazi            26
# 8   022-14-110601  BS(CS)                  Areesha Sohail            19
# 9   022-14-110599  BS(CS)                         Arsalan            28
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi            30
# 11  022-14-110591  BS(CS)                     Habib Ullah            28
# ...

# %%
data.iloc[2]
# Out:
# Student Code            022-14-110585
# Degree                         BS(CS)
# Student_Name             Afrah Zareen
# Mid                                18
# Quiz 1                           Null
# Quiz 2                              2
# Best of Quizzes                     5
# Assignment_1                        8
# Assignment 2                       10
# Best of Assignments                10
# Total Sessional (50)               33
# Final_50                           30
# Total_100                          63
# Grade                               C
# True_values                       yes
# False_values                 avalible
# Name: 2, dtype: object

# %%
#fancy values

data.iloc[[0,3]]
# Out:
#    Student Code  Degree    Student_Name           Mid Quiz 1 Quiz 2  \
# 0  022-14-19987  BS(CS)     Abdul Basit  not avalible      8   Null
# 3  022-14-19718  BS(CS)  Ahmed Ali Raza            14      7      2
#
#   Best of Quizzes Assignment_1  Assignment 2  Best of Assignments  \
# 0               8            7  not avalible                  9.0
# 3               7          NaN             2                  2.0
#
#    Total Sessional (50) Final_50  Total_100 Grade True_values False_values
# 0                  45.0       25       70.0     B         yes           No
# 3                  23.0      NaN       46.0     F         yes           No

# %%
data.iloc[0,1:4]
# Out:
# Degree                BS(CS)
# Student_Name     Abdul Basit
# Mid             not avalible
# Name: 0, dtype: object
